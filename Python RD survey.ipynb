# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_excel('/Users/mr.basix/Documents/Sync/Academics/USF/Research/Reverse Diet/RDS Clean.xlsx', engine='openpyxl')

# %%
df_cleaned = df.drop(columns=['ResponseId', 'Q1', 'Q2'])

# %%
print(df_cleaned.head())
# Out:
#    Q3 clean                             Q3  Q4 Clean         Q4  Q5 Clean  \
# 0         2   Lifestyle/General population          4  >8 years         1
# 1         2   Lifestyle/General population          4  >8 years         1
# 2         2   Lifestyle/General population          4  >8 years         1
# 3         1  Competitive physique athletes          1  <2 years         1
# 4         1  Competitive physique athletes          1  <2 years         1
#
#              Q5   Q6   Q7  Q8 Clean                   Q8  Q9 Clean  \
# 0  I coach both  Yes   No       1.0  I focus on Calories       1.0
# 1  I coach both  Yes   No       1.0  I focus on Calories       1.0
# 2  I coach both  Yes   No       1.0  I focus on Calories       1.0
# 3  I coach both   No  Yes       1.0  I focus on Calories       1.0
# 4  I coach both  Yes  Yes       1.0  I focus on Calories       1.0
#
#              Q9  Q10 clean (Male kcal)  Q11 Clean (female kcal)  \
# ...

# %%
#What category does a majority of your clientele (coaching) fall under? 

value_counts = df_cleaned['Q3 clean'].value_counts()


percentages = ((value_counts / value_counts.sum()) * 100).round(0)


print(percentages)


# Define a dictionary to map the old values to the new ones
rename_map = {
    1: 'Competitive physique athletes',
    2: 'Lifestyle/General population',
    3: 'Strength Athletes',
    4: 'Team sports/Athletic performance'
}

# Rename the categories in 'Q3 clean'
df_cleaned['Q3 clean'] = df_cleaned['Q3 clean'].replace(rename_map)

# Count occurrences of each unique value in 'Q3 clean' after renaming
value_counts = df_cleaned['Q3 clean'].value_counts()

# Calculate percentages
percentages = (value_counts / value_counts.sum()) * 100

# Create the pie chart
plt.figure(figsize=(8, 8))  # Set the figure size for better readability
plt.pie(percentages, labels=percentages.index, autopct='%1.0f%%', startangle=140)
plt.title('What category does a majority of your clientele (coaching) fall under? ')
plt.axis('equal')  # Equal aspect ratio ensures the pie chart is circular.

# Display the pie chart
plt.show()

#Bar Graph 
value_counts = df_cleaned['Q3 clean'].value_counts()

percentages = (value_counts / value_counts.sum()) * 100


plt.figure(figsize=(10, 6))  # Set the figure size for better readability
plt.bar(percentages.index, percentages, color='skyblue')
plt.title('What category does a majority of your clientele (coaching) fall under? ')
plt.xlabel('Category')
plt.ylabel('Percentage')
plt.xticks(rotation=45)  # Rotate category labels for better readability

# Display the bar graph
plt.show()
# Out:
# Q3 clean
# 2    82.0
# 1    12.0
# 3     4.0
# 4     2.0
# Name: count, dtype: float64

# %%
#How long have you been coaching?

value_counts = df_cleaned['Q4 Clean '].value_counts()


percentages = ((value_counts / value_counts.sum()) * 100).round(0)


print(percentages)


# Define a dictionary to map the old values to the new ones
rename_map = {
    1: '< 2 years',
    2: '2-4 years',
    3: '5-8 years',
    4: '>8 years'
}

# Rename the categories in 'Q4 clean'
df_cleaned['Q4 Clean '] = df_cleaned['Q4 Clean '].replace(rename_map)

# Count occurrences of each unique value in 'Q3 clean' after renaming
value_counts = df_cleaned['Q4 Clean '].value_counts()

# Calculate percentages
percentages = (value_counts / value_counts.sum()) * 100

# Create the pie chart
plt.figure(figsize=(8, 8))  # Set the figure size for better readability
plt.pie(percentages, labels=percentages.index, autopct='%1.0f%%', startangle=140)
plt.title('How long have you been coaching?')
plt.axis('equal')  # Equal aspect ratio ensures the pie chart is circular.

# Display the pie chart
plt.show()

#Bar Graph 
value_counts = df_cleaned['Q4 Clean '].value_counts()

percentages = (value_counts / value_counts.sum()) * 100


plt.figure(figsize=(10, 6))  # Set the figure size for better readability
plt.bar(percentages.index, percentages, color='skyblue')
plt.title('How long have you been coaching?')
plt.xlabel('Category')
plt.ylabel('Percentage')
plt.xticks(rotation=45)  # Rotate category labels for better readability

# Display the bar graph
plt.show()
# Out:
# Q4 Clean
# 2    40.0
# 3    27.0
# 4    22.0
# 1    12.0
# Name: count, dtype: float64

# %%
#Do you coach clients that are natural, enhanced, or both?

value_counts = df_cleaned['Q5 Clean'].value_counts()


percentages = ((value_counts / value_counts.sum()) * 100).round(0)


print(percentages)


# Define a dictionary to map the old values to the new ones
rename_map = {
    1: 'I coach both',
    2: 'I only coach natural athletes',
    3: 'I only Coach Enhanced Athletes(e.g. PEDs, HGH, Insulin)',
}

# Rename the categories in 'Q3 clean'
df_cleaned['Q5 Clean'] = df_cleaned['Q5 Clean'].replace(rename_map)

# Count occurrences of each unique value in 'Q3 clean' after renaming
value_counts = df_cleaned['Q5 Clean'].value_counts()

# Calculate percentages
percentages = (value_counts / value_counts.sum()) * 100

# Create the pie chart
plt.figure(figsize=(8, 8))  # Set the figure size for better readability
plt.pie(percentages, labels=percentages.index, autopct='%1.0f%%', startangle=140)
plt.title('Do you coach clients that are natural, enhanced, or both?')
plt.axis('equal')  # Equal aspect ratio ensures the pie chart is circular.

# Display the pie chart
plt.show()

#Bar Graph 
value_counts = df_cleaned['Q5 Clean'].value_counts()

percentages = (value_counts / value_counts.sum()) * 100


plt.figure(figsize=(10, 6))  # Set the figure size for better readability
plt.bar(percentages.index, percentages, color='skyblue')
plt.title('Do you coach clients that are natural, enhanced, or both?')
plt.xlabel('Category')
plt.ylabel('Percentage')
plt.xticks(rotation=45)  # Rotate category labels for better readability

# Display the bar graph
plt.show()
# Out:
# Q5 Clean
# 2    71.0
# 1    29.0
# Name: count, dtype: float64

# %%
#After completion of a caloric deficit (fat loss phase) in your natural athletes, do you purposely increase calories for your clients? 
value_counts = df_cleaned['Q6'].value_counts()


percentages = ((value_counts / value_counts.sum()) * 100).round(0)


print(percentages)


# Define a dictionary to map the old values to the new ones
rename_map = {
    1: 'Yes',
    2: 'No',
}

# Rename the categories in 'Q3 clean'
df_cleaned['Q6'] = df_cleaned['Q6'].replace(rename_map)

# Count occurrences of each unique value in 'Q3 clean' after renaming
value_counts = df_cleaned['Q6'].value_counts()

# Calculate percentages
percentages = (value_counts / value_counts.sum()) * 100

# Create the pie chart
plt.figure(figsize=(8, 8))  # Set the figure size for better readability
plt.pie(percentages, labels=percentages.index, autopct='%1.0f%%', startangle=140)
plt.title('After completion of a caloric deficit (fat loss phase) in your natural athletes, do you purposely increase calories for your clients?')
plt.axis('equal')  # Equal aspect ratio ensures the pie chart is circular.

# Display the pie chart
plt.show()

#Bar Graph 
value_counts = df_cleaned['Q6'].value_counts()

percentages = (value_counts / value_counts.sum()) * 100


plt.figure(figsize=(10, 6))  # Set the figure size for better readability
plt.bar(percentages.index, percentages, color='skyblue')
plt.title('After completion of a caloric deficit (fat loss phase) in your natural athletes, do you purposely increase calories for your clients?')
plt.xlabel('Category')
plt.ylabel('Percentage')
plt.xticks(rotation=45)  # Rotate category labels for better readability

# Display the bar graph
plt.show()
# Out:
# Q6
# Yes    95.0
# No      5.0
# Name: count, dtype: float64

# %%
#In your natural athletes, do you utilize what you would consider is a "reverse dieting" approach?
value_counts = df_cleaned['Q7'].value_counts()


percentages = ((value_counts / value_counts.sum()) * 100).round(0)


print(percentages)


# Define a dictionary to map the old values to the new ones
rename_map = {
    1: 'Yes',
    2: 'No',
}

# Rename the categories in 'Q3 clean'
df_cleaned['Q7'] = df_cleaned['Q7'].replace(rename_map)

# Count occurrences of each unique value in 'Q3 clean' after renaming
value_counts = df_cleaned['Q7'].value_counts()

# Calculate percentages
percentages = (value_counts / value_counts.sum()) * 100

# Create the pie chart
plt.figure(figsize=(8, 8))  # Set the figure size for better readability
plt.pie(percentages, labels=percentages.index, autopct='%1.0f%%', startangle=140)
plt.title('In your natural athletes, do you utilize what you would consider is a "reverse dieting" approach?')
plt.axis('equal')  # Equal aspect ratio ensures the pie chart is circular.

# Display the pie chart
plt.show()

#Bar Graph 
value_counts = df_cleaned['Q7'].value_counts()

percentages = (value_counts / value_counts.sum()) * 100


plt.figure(figsize=(10, 6))  # Set the figure size for better readability
plt.bar(percentages.index, percentages, color='skyblue')
plt.title('In your natural athletes, do you utilize what you would consider is a "reverse dieting" approach?')
plt.xlabel('Category')
plt.ylabel('Percentage')
plt.xticks(rotation=45)  # Rotate category labels for better readability

# Display the bar graph
plt.show()
# Out:
# Q7
# Yes    84.0
# No     16.0
# Name: count, dtype: float64

# %%
#When implementing a reverse diet for natural clients, do you primarily focus on manipulating specific macronutrients or general caloric intake?
 
value_counts = df_cleaned['Q8 Clean'].value_counts()


percentages = ((value_counts / value_counts.sum()) * 100).round(0)


print(percentages)


# Define a dictionary to map the old values to the new ones
rename_map = {
    1: 'I focus on Calories',
    2: 'I focus on Macronutrients',
}

# Rename the categories in 'Q8 clean'
df_cleaned['Q8 Clean'] = df_cleaned['Q8 Clean'].replace(rename_map)

# Count occurrences of each unique value in 'Q3 clean' after renaming
value_counts = df_cleaned['Q8 Clean'].value_counts()

# Calculate percentages
percentages = (value_counts / value_counts.sum()) * 100

# Create the pie chart
plt.figure(figsize=(8, 8))  # Set the figure size for better readability
plt.pie(percentages, labels=percentages.index, autopct='%1.0f%%', startangle=140)
plt.title('When implementing a reverse diet for natural clients, do you primarily focus on manipulating specific macronutrients or general caloric intake?')
plt.axis('equal')  # Equal aspect ratio ensures the pie chart is circular.

# Display the pie chart
plt.show()

#Bar Graph 
value_counts = df_cleaned['Q8 Clean'].value_counts()

percentages = (value_counts / value_counts.sum()) * 100


plt.figure(figsize=(10, 6))  # Set the figure size for better readability
plt.bar(percentages.index, percentages, color='skyblue')
plt.title('When implementing a reverse diet for natural clients, do you primarily focus on manipulating specific macronutrients or general caloric intake?')
plt.xlabel('Category')
plt.ylabel('Percentage')
plt.xticks(rotation=45)  # Rotate category labels for better readability

# Display the bar graph
plt.show()
# Out:
# Q8 Clean
# 2.0    65.0
# 1.0    35.0
# Name: count, dtype: float64

# %%
#Does your clientele consist of primarily men, women, or both?  
value_counts = df_cleaned['Q9 Clean'].value_counts()


percentages = ((value_counts / value_counts.sum()) * 100).round(0)


print(percentages)


# Define a dictionary to map the old values to the new ones
rename_map = {
    1: 'I coach both',
    2: 'I coach only men',
    3: 'I coach only women'
}

# Rename the categories in 'Q8 clean'
df_cleaned['Q9 Clean'] = df_cleaned['Q9 Clean'].replace(rename_map)

# Count occurrences of each unique value in 'Q3 clean' after renaming
value_counts = df_cleaned['Q9 Clean'].value_counts()

# Calculate percentages
percentages = (value_counts / value_counts.sum()) * 100

# Create the pie chart
plt.figure(figsize=(8, 8))  # Set the figure size for better readability
plt.pie(percentages, labels=percentages.index, autopct='%1.0f%%', startangle=140)
plt.title('Does your clientele consist of primarily men, women, or both?')
plt.axis('equal')  # Equal aspect ratio ensures the pie chart is circular.

# Display the pie chart
plt.show()

#Bar Graph 
value_counts = df_cleaned['Q9 Clean'].value_counts()

percentages = (value_counts / value_counts.sum()) * 100


plt.figure(figsize=(10, 6))  # Set the figure size for better readability
plt.bar(percentages.index, percentages, color='skyblue')
plt.title('Does your clientele consist of primarily men, women, or both? ')
plt.xlabel('Category')
plt.ylabel('Percentage')
plt.xticks(rotation=45)  # Rotate category labels for better readability

# Display the bar graph
plt.show()
# Out:
# Q9 Clean
# 1.0    71.0
# 3.0    27.0
# 2.0     2.0
# Name: count, dtype: float64

# %%
# Assuming 'Q10 clean (Male kcal)' is the correct column name
# Check if the column exists in the DataFrame
if 'Q10 clean (Male kcal)' in df_cleaned.columns:
    # Obtain descriptive statistics
    descriptives = df_cleaned['Q10 clean (Male kcal)'].describe()
    print(descriptives)
else:
    print("Column 'Q10 clean (Male kcal)' does not exist in the DataFrame. Please check the correct column name.")
# Out:
# count      47.000000
# mean      155.255319
# std       171.874128
# min        11.000000
# 25%        50.000000
# 50%       100.000000
# 75%       200.000000
# max      1000.000000
# Name: Q10 clean (Male kcal), dtype: float64

# %%
# Ensure the column exists
if 'Q10 clean (Male kcal)' in df_cleaned.columns:
    # Calculate the average increase
    average_increase = df_cleaned['Q10 clean (Male kcal)'].mean()
    
    # Round the results to one decimal place
    average_increase_rounded = round(average_increase, 1)
    relative_increase_rounded = round(average_increase_rounded / 100, 1)  # per kg
    percentage_increase_rounded = round((average_increase_rounded / 2000) * 100, 1)  # Convert to percentage
    
    # Print out the rounded results
    print(f"Average daily caloric increase: {average_increase_rounded} calories")
    print(f"Relative daily caloric increase per kg body weight: {relative_increase_rounded} calories")
    print(f"Percentage increase relative to 2000 calories: {percentage_increase_rounded}%")
else:
    print("Column 'Q10 clean (Male kcal)' does not exist in the DataFrame. Please check the correct column name.")
# Out:
# Average daily caloric increase: 155.3 calories
# Relative daily caloric increase per kg body weight: 1.6 calories
# Percentage increase relative to 2000 calories: 7.8%

# %%
# Check if both columns exist in the DataFrame
if 'Q10 clean (Male kcal)' in df_cleaned.columns and 'Q27 Clean (Male Macro)' in df_cleaned.columns:
    # Combine the two series, ignoring NaN values from both
    combined = pd.concat([df_cleaned['Q10 clean (Male kcal)'].dropna(), df_cleaned['Q27 Clean (Male Macro)'].dropna()])
    
    # Calculate the average of the combined data, excluding NaN values
    combined_average = combined.mean()
    
    # Calculate the rounded average (absolute value)
    absolute_average_rounded = round(combined_average, 1)
    
    # Calculate the relative value based on body weight (assuming 100kg)
    relative_average_rounded = round(absolute_average_rounded / 100, 1)  # per kg
    
    # Calculate the percentage increase based on a standard (e.g., 2000 calories)
    percentage_average_rounded = round((absolute_average_rounded / 2000) * 100, 1)  # Convert to percentage
    
    # Print out the results
    print(f"(Male)Average weekly combined value (absolute): {absolute_average_rounded} calories")
    print(f"(Male)Relative value based on body weight (100kg): {relative_average_rounded} calories/kg")
    print(f"(Male)Percentage of the standard 2000 calories: {percentage_average_rounded}%")
else:
    print("One or both of the columns 'Q10 clean (Male kcal)' and 'Q27 Clean (Male Macro)' do not exist in the DataFrame. Please check the correct column names.")
# Out:
# (Male)Average weekly combined value (absolute): 169.1 calories
# (Male)Relative value based on body weight (100kg): 1.7 calories/kg
# (Male)Percentage of the standard 2000 calories: 8.5%

# %%
# Check if both columns exist in the DataFrame
if 'Q11 Clean (female kcal)' in df_cleaned.columns and 'Q26 Clean (Female (macro and kcal)' in df_cleaned.columns:
    # Combine the two series, ignoring NaN values from both
    combined_female_macros = pd.concat([df_cleaned['Q11 Clean (female kcal)'].dropna(), df_cleaned['Q26 Clean (Female (macro and kcal)'].dropna()])
    
    # Calculate the average of the combined data, excluding NaN values
    combined_female_macros_average = combined_female_macros.mean()
    
    # Calculate the rounded average (absolute value)
    absolute_female_macros_average_rounded = round(combined_female_macros_average, 1)
    
    # Calculate the relative value based on body weight (for a 60kg female)
    relative_female_macros_average_rounded = round(absolute_female_macros_average_rounded / 60, 1)  # per kg
    
    # Calculate the percentage increase based on the ending calories (1000 calories)
    percentage_female_macros_average_rounded = round((absolute_female_macros_average_rounded / 1000) * 100, 1)  # Convert to percentage
    
    # Print out the results
    print(f"(Female)Average weekly total macronutrient increase (absolute): {absolute_female_macros_average_rounded} (kcal)")
    print(f"(Female)Relative daily total macronutrient increase per kg body weight (for a 60kg female): {relative_female_macros_average_rounded} (g or kcal/kg)")
    print(f"(Female)Percentage increase relative to 1000 calories: {percentage_female_macros_average_rounded}%")
else:
    print("One or both of the columns 'Q11 Clean (female kcal)' and 'Q26 Clean (Female (macro and kcal)' do not exist in the DataFrame. Please check the correct column names.")
# Out:
# (Female)Average weekly total macronutrient increase (absolute): 116.7 (kcal)
# (Female)Relative daily total macronutrient increase per kg body weight (for a 60kg female): 1.9 (g or kcal/kg)
# (Female)Percentage increase relative to 1000 calories: 11.7%

# %%
# Check if the column exists in the DataFrame
if 'Q12 Clean' in df_cleaned.columns:
    # Obtain descriptive statistics for 'Q12 Clean' and round to one decimal
    descriptives_q12_clean = df_cleaned['Q12 Clean'].describe().round(1)
    
    # Print the descriptive statistics rounded to one decimal
    print(descriptives_q12_clean)
else:
    print("Column 'Q12 Clean' does not exist in the DataFrame. Please check the correct column name.")
# Out:
# count    66.0
# mean      8.7
# std       3.6
# min       3.0
# 25%       6.0
# 50%       8.0
# 75%      10.0
# max      24.0
# Name: Q12 Clean, dtype: float64

# %%
#How do you adjust cardio/step count once the fat loss phase is completed
value_counts = df_cleaned['Q14 Clean'].value_counts()


percentages = ((value_counts / value_counts.sum()) * 100).round(0)


print(percentages)


# Define a dictionary to map the old values to the new ones
rename_map = {
    1: 'Decrease',
    2: 'Increase',
    3: 'No change'
}

# Rename the categories in 'Q8 clean'
df_cleaned['Q14 Clean'] = df_cleaned['Q14 Clean'].replace(rename_map)

# Count occurrences of each unique value in 'Q3 clean' after renaming
value_counts = df_cleaned['Q14 Clean'].value_counts()

# Calculate percentages
percentages = (value_counts / value_counts.sum()) * 100

# Create the pie chart
plt.figure(figsize=(8, 8))  # Set the figure size for better readability
plt.pie(percentages, labels=percentages.index, autopct='%1.0f%%', startangle=140)
plt.title('How do you adjust cardio/step count once the fat loss phase is completed')
plt.axis('equal')  # Equal aspect ratio ensures the pie chart is circular.

# Display the pie chart
plt.show()

#Bar Graph 
value_counts = df_cleaned['Q14 Clean'].value_counts()

percentages = (value_counts / value_counts.sum()) * 100


plt.figure(figsize=(10, 6))  # Set the figure size for better readability
plt.bar(percentages.index, percentages, color='skyblue')
plt.title('How do you adjust cardio/step count once the fat loss phase is completed')
plt.xlabel('Category')
plt.ylabel('Percentage')
plt.xticks(rotation=45)  # Rotate category labels for better readability

# Display the bar graph
plt.show()
# Out:
# Q14 Clean
# 1.0    74.0
# 3.0    23.0
# 2.0     3.0
# Name: count, dtype: float64
